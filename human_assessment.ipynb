# %% [markdown]
# # Load packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load dataset

# %%
A_raw_df = pd.read_excel("C:/Users/a1003/OneDrive/桌面/Thesis/excel_csv/new_assessment/Anna_Radetzky_OLST_assessment_process.xlsx")
J_raw_df = pd.read_excel("C:/Users/a1003/OneDrive/桌面/Thesis/excel_csv/new_assessment/Johanna_Dinkels_OLST_assessment_vollstandig_process.xlsx")
E_raw_df = pd.read_csv("C:/Users/a1003/OneDrive/桌面/Thesis/excel_csv/new_assessment/OLST_assessment_Eva_12062022.csv")

# %%
A_raw_df
# Out:
#           sub_ID  first_rate second_rate  \
# 0   sub_01_EC_W2         3.0        Good
# 1   sub_01_EP_W2         0.5        Good
# 2   sub_02_EC_W2         8.0         Bad
# 3   sub_02_EP_W2         0.5        Good
# 4   sub_03_EC_W2         5.0    Moderate
# 5   sub_03_EP_W2         1.0        Good
# 6   sub_04_EC_W2         0.0        Good
# 7   sub_04_EP_W2         0.0        Good
# 8   sub_05_EC_W2         3.5    Moderate
# 9   sub_06_EC_W2         0.5        Good
# 10  sub_06_EP_W2         0.5        Good
# 11  sub_07_EC_W2         6.0    Moderate
# 12  sub_07_EP_W2         0.5        Good
# 13  sub_08_EC_W2         0.0        Good
# 14  sub_08_EP_W2         0.0        Good
# 15  sub_09_EC_W2         3.5    Moderate
# 16  sub_09_EP_W2         1.0        Good
# 17  sub_10_EC_W2         6.5    Moderate
# 18  sub_10_EP_W2         0.5        Good
# 19  sub_11_EC_W2         1.5        Good
# 20  sub_11_EP_W2         0.0        Good
# 21  sub_12_EC_W2         4.5    Moderate
# 22  sub_13_EC_W2         5.0    Moderate
# 23  sub_13_EP_W2         0.5        Good
# 24  sub_14_EC_W2         1.5        Good
# 25  sub_14_EP_W2         0.0        Good
# 26  sub_16_EC_W2         4.0    Moderate
# 27  sub_16_EP_W2         1.0        Good
# 28  sub_17_EC_W2         0.0        Good
# 29  sub_17_EP_W2         0.0        Good
# 30  sub_18_EC_W2         6.5    Moderate
# 31  sub_18_EP_W2         0.0        Good
# 32  sub_19_EC_W2         6.5    Moderate
# 33  sub_19_EP_W2         1.0        Good
# 34  sub_23_EC_W2         5.0    Moderate
# 35  sub_23_EP_W2         0.0        Good
# 36  sub_24_EC_W2         7.0         Bad
# 37  sub_25_EC_W2         8.5         Bad
# 38  sub_25_EP_W2         6.5    Moderate
# 39  sub_26_EC_W2         5.5    Moderate
# 40  sub_27_EC_W2         5.0    Moderate
# 41  sub_27_EP_W2         0.0        Good
# 42  sub_28_EC_W2         3.0        Good
# 43  sub_28_EP_W2         NaN        Good
# 44  sub_29_EC_W2         2.0        Good
# 45  sub_29_EP_W2         0.0        Good
# 46  sub_30_EC_W2         7.5         Bad
# 47  sub_30_EP_W2         2.5        Good
# 48  sub_31_EC_W2         8.0         Bad
# 49  sub_31_EP_W2         1.0        Good
# 50  sub_05_EP_W2         0.0        Good
# 51  sub_15_EC_W2         3.0        Good
# 52  sub_15_EP_W2         0.0        Good
# 53  sub_24_EP_W2         5.0    Moderate
# 54  sub_26_EP_W2         1.0        Good
#
#                                         rating reason   it1   it2  it3  it4  \
# 0      body swaying but no arms used or toe tap downs   0.0   3.0  0.0  0.0
# 1   body only slightly swaying, no arms used or to...   0.0   0.0  0.0  0.0
# 2   body swaying a lot, arms used multiple times a...   1.0   3.0  4.0  4.0
# 3                             almost no body swaying    0.0   0.0  0.0  0.0
# 4      little body swaying, stepping but no arms used   0.0   3.0  3.0  0.0
# 5          stands almost still, but repositioned arms   1.0   0.0  0.0  2.0
# 6                                 stands almost still   0.0   0.0  0.0  0.0
# 7                                 stands almost still   0.0   0.0  0.0  0.0
# 8   in comparison a lot of movement to balance it out   7.0   0.0  0.0  1.0
# 9          stands almost still, lifts every hand once   0.0   0.0  0.0  2.0
# 10              stands almost still, lifts hands once   0.0   0.0  0.0  1.0
# 11  a lot of leg/ foot movement, but less upper bo...   0.0   8.0  3.0  0.0
# 12                       very good and balanced stand   0.0   0.0  0.0  0.0
# 13                                 almost no movement   1.0   0.0  0.0  0.0
# 14                                 almost no movement   0.0   0.0  0.0  0.0
# 15                             lifted leg moves a lot   4.0   1.0  1.0  0.0
# 16                                 almost no movement   0.0   0.0  0.0  0.0
# 17         tried to balance it out, not stepping down   2.0  12.0  0.0  1.0
# 18                          only slight leg movements   0.0   0.0  0.0  0.0
# 19       does a good job balancing it out on one foot   7.0   3.0  0.0  0.0
# 20                                 almost no movement   0.0   0.0  0.0  0.0
# 21  feels like him/her not balancing instead using...   0.0   2.0  2.0  1.0
# 22                                 body swaying a lot   0.0   8.0  2.0  0.0
# 23                              really balanced stand   0.0   1.0  0.0  0.0
# 24      stepping down, but minimal movement otherwise   0.0   1.0  1.0  0.0
# 25                                   minimal movement   0.0   0.0  0.0  0.0
# 26    some more but clear movements to balance it out   1.0   3.0  2.0  0.0
# 27                 so balanced but stepping down once   0.0   0.0  1.0  0.0
# 28                                        so balanced   0.0   0.0  0.0  0.0
# 29                                       so balanced!   0.0   0.0  0.0  0.0
# 30    a lot of stumbling but less upper body movement   4.0   4.0  4.0  0.0
# 31                                 almost no movement   0.0   0.0  0.0  0.0
# 32                                   a lot of swaying   0.0   7.0  0.0  2.0
# 33                                good balanced stand   0.0   0.0  0.0  1.0
# 34                   a lot of stumbling/ tapping down   2.0   0.0  7.0  0.0
# 35                                   really balanced    0.0   0.0  0.0  0.0
# 36                     could barely stand on one foot   1.0   8.0  5.0  0.0
# 37                     could barely stand on one foot   5.0   8.0  5.0  0.0
# 38            hard to decide between moderate and bad   7.0   7.0  2.0  0.0
# 39       a lot stepping down but less other movements   9.0   4.0  6.0  0.0
# 40                                 a lot of stumbling  10.0   3.0  5.0  0.0
# 41                    stands almost perfect balanced    1.0   0.0  0.0  0.0
# 42                                   uses hands a lot   2.0   2.0  0.0  4.0
# 43                          its a good balanced stand   6.0   2.0  0.0  0.0
# 44                          its a good balanced stand   2.0   5.0  0.0  0.0
# 45                               seems almost perfect   0.0   0.0  0.0  0.0
# 46                       a lot of different movements   5.0   0.0  5.0  2.0
# 47                                         no swaying   0.0   0.0  0.0  2.0
# 48             al lot stepping down and foot movement   9.0   3.0  6.0  0.0
# 49                                good balanced stand   0.0   0.0  0.0  0.0
# 50                                good balanced stand   4.0   0.0  0.0  0.0
# 51                           a little bit of swaying    3.0   7.0  0.0  0.0
# 52                                 almost no movement   0.0   0.0  0.0  0.0
# 53                                 almost no movement   1.0   5.0  1.0  0.0
# 54                          little bit of leg swaying   2.0   3.0  0.0  0.0
#
#     it5                                     other comments
# 0   0.0                                                NaN
# 1   0.0                                                NaN
# 2   0.0                                                NaN
# 3   0.0                                                NaN
# 4   0.0                                                NaN
# 5   0.0                                                NaN
# 6   0.0                                                NaN
# 7   0.0                                                NaN
# 8   0.0                                                NaN
# 9   0.0                                                NaN
# 10  0.0                                      easy to rate
# 11  0.0  first one standing on left leg, different pers...
# 12  0.0  first one standing on left leg, different pers...
# 13  0.0                     easy to rate, standing on left
# 14  0.0                     easy to rate, standing on left
# 15  0.0                            foot movement difficult
# 16  0.0                            foot movement difficult
# 17  0.0  a lot of leg movement, questioning wether its ...
# 18  0.0  easy to rate, because of less movement than ot...
# 19  0.0                30 degrees abduction hard to define
# 20  0.0                                       easy to rate
# 21  0.0             a lot of movement in the high hold leg
# 22  0.0                                                NaN
# 23  0.0                          easy one, clear movements
# 24  0.0  holds foot deep down so couldn't really tell i...
# 25  0.0                           very good balanced stand
# 26  0.0                       clear movements easy to rate
# 27  0.0                                       easy to rate
# 28  0.0                                       easy to rate
# 29  0.0                                       easy to rate
# 30  0.0                              hard to rate forefoot
# 31  0.0                                       easy to rate
# 32  1.0                             holds leg in abduction
# 33  0.0                                       easy to rate
# 34  0.0                                       easy to rate
# 35  0.0                                       easy to rate
# 36  0.0                             lifted whole foot once
# 37  2.0  how to rate a knee lift, lifts standing foot a...
# 38  0.0                      hard to rate the leg movement
# 39  0.0  hard to define single abduction movements, use...
# 40  0.0  first one to lift heel way more often than for...
# 41  0.0                                       easy to rate
# 42  0.0              easy to rate because low leg movement
# 43  0.0  uses his foot a lot to balance hard to rate i ...
# 44  0.0   hard to rate if its a new abduction movement ...
# 45  0.0                                                NaN
# 46  0.0            clear but al lot of different movements
# 47  0.0                  hard to rate lifted foot movement
# 48  0.0                 lifted whole standing foot 2 times
# 49  0.0                                       easy to rate
# 50  0.0                                       easy to rate
# 51  0.0  hard to rate abduction movement because of deg...
# 52  0.0                                       easy to rate
# 53  0.0                    hard to rate abduction/ flexion
# 54  0.0                                       easy to rate

# %%
E_raw_df
# Out:
#           sub_ID  first_rate second_rate  \
# 0            NaN         0.5        Good
# 1   sub_01_EP_W2         0.5        Good
# 2   sub_01_EC_W2         2.5        Good
# 3   sub_02_EP_W2         1.0        Good
# 4   sub_02_EC_W2         8.0         Bad
# 5   sub_03_EC_W2         7.5         Bad
# 6   sub_03_EP_W2         0.0        Good
# 7   sub_04_EC_W2         0.0        Good
# 8   sub_04_EP_W2         0.0        Good
# 9   sub_05_EC_W2        10.0         Bad
# 10  sub_05_EP_W2         2.5    Moderate
# 11  sub_06_EC_W2         0.5        Good
# 12  sub_06_EP_W2         0.0        Good
# 13  sub_07_EC_W2         6.5    Moderate
# 14  sub_07_EP_W2         0.0        Good
# 15  sub_08_EC_W2         0.5        Good
# 16  sub_08_EP_W2         0.0        Good
# 17  sub_09_EC_W2         5.0    Moderate
# 18  sub_09_EP_W2         0.5        Good
# 19  sub_10_EC_W2         6.0    Moderate
# 20  sub_10_EP_W2         0.0        Good
# 21  sub_11_EC_W2         1.5        Good
# 22  sub_11_EP_W2         0.0        Good
# 23  sub_12_EC_W2         3.5    Moderate
# 24  sub_13_EC_W2         4.0    Moderate
# 25  sub_13_EP_W2         0.5        Good
# 26  sub_14_EC_W2         1.0        Good
# 27  sub_14_EP_W2         0.0        Good
# 28  sub_15_EC_W2         1.0        Good
# 29  sub_15_EP_W2         0.0        Good
# 30  sub_16_EC_W2         0.5        Good
# 31  sub_16_EP_W2         1.0        Good
# 32  sub_17_EC_W2         0.5        Good
# 33  sub_17_EP_W2         0.0        Good
# 34  sub_18_EC_W2         7.0         Bad
# 35  sub_18_EP_W2         0.0        Good
# 36  sub_19_EC_W2         6.5         Bad
# 37  sub_19_EP_W2         0.0        Good
# 38  sub_20_EP_W2         0.5        Good
# 39  sub_23_EC_W2         2.5    Moderate
# 40  sub_23_EP_W2         0.5        Good
# 41  sub_24_EC_W2         8.0         Bad
# 42  sub_24_EP_W2         1.5        Good
# 43  sub_25_EC_W2         8.5         Bad
# 44  sub_25_EP_W2         7.5         Bad
# 45  sub_26_EC_W2         8.0         Bad
# 46  sub_26_EP_W2         0.5        Good
# 47  sub_27_EC_W2         5.0    Moderate
# 48  sub_27_EP_W2         0.5        Good
# 49  sub_28_EC_W2         0.5        Good
# 50  sub_28_EP_W2         0.0        Good
# 51  sub_29_EC_W2         0.5        Good
# 52  sub_29_EP_W2         0.0        Good
# 53  sub_30_EC_W2         3.5    Moderate
# 54  sub_30_EP_W2         0.5        Good
# 55  sub_31_EC_W2         8.5         Bad
# 56  sub_31_EP_W2         0.0        Good
#
#                                         rating reason  it1  it2  it3  it4  \
# 0                                        did not move    0    0    0    0
# 1                                        did not move    0    0    0    0
# 2                          2 to 3 balancing movements    0    1    0    0
# 3                                                good    0    0    0    0
# 4                    foot on the ground several times    0    2    5    1
# 5                             touched several times.     2    2    4    0
# 6                                        did not move    0    0    0    0
# 7                                        did not move    0    0    0    0
# 8                                        did not move    0    0    0    0
# 9                      touched a lot, shaking a lot.     0    6    7    9
# 10                                  shaking, but fine    0    0    0    0
# 11                                               good    0    0    0    0
# 12                                               good    0    0    0    0
# 13                             several moving, but ok    0    4    3    0
# 14                                         no moving     0    0    0    0
# 15                                  barely no moving     0    1    0    0
# 16                                         no moving     0    0    0    0
# 17                    touched a bit, lots of shaking     0    1    2    0
# 18                                     a lil shaking     0    0    0    0
# 19  lots of shaking, but feet never touches the gr...    0    8    0    1
# 20                                               good    0    0    0    0
# 21                                     good, shaking     2    0    0    0
# 22                                             good,     0    0    0    0
# 23                                    several touches    0    1    2    0
# 24                          several touches, shaking     0    5    1    0
# 25                                              good     0    2    0    0
# 26                     good, touched the ground once     0    1    1    0
# 27                                              good     0    0    0    0
# 28                                    good, shaking      0    2    0    0
# 29                                              good,    0    0    0    0
# 30                                               good    0    0    2    0
# 31                            good, but touched once     0    0    1    0
# 32                                               good    0    1    0    0
# 33                                          very good    0    0    0    0
# 34  touched several times, lots of shaking and bal...    2    3    4    0
# 35                                              good     0    0    0    0
# 36  raising leg shaking a lot, standing leg shakin...    1    7    1    1
# 37                                               good    0    0    0    0
# 38                                               good    0    0    0    0
# 39                                 good, but touched     0    0    3    0
# 40                                               good    0    0    0    0
# 41  switched feet at the beginning, and touched th...    2    4    6    0
# 42                                                ok     0    3    1    0
# 43                                   not good at all     5    8    4    0
# 44         for someone whose eyes are open, it's bad     3   10    2    0
# 45                     several touches and balancing     4    6    5    6
# 46                                                 ok    0    1    0    0
# 47                                    ok but touched     0    0    4    0
# 48                                              good     0    0    0    0
# 49                                              good     0    4    0    3
# 50                           good, barely no shaking     0    0    0    0
# 51                      barely no balancing movement     1    3    0    0
# 52                                               good    0    0    0    0
# 53                                   could be better     1    0    5    0
# 54                                              good     0    0    1    0
# 55                                          not good     5    3    1    6
# 56                                              good     0    0    0    0
#
#     it5                     other comments
# 0     0                                NaN
# 1     0                                NaN
# 2     0                                NaN
# 3     0                                NaN
# 4     0                                NaN
# 5     0                                NaN
# 6     0                                NaN
# 7     0                                NaN
# 8     0                                NaN
# 9     0                                NaN
# 10    0                                  `
# 11    0                                NaN
# 12    0                                NaN
# 13    0                                NaN
# 14    0                                NaN
# 15    0                                NaN
# 16    0                                NaN
# 17    0                                NaN
# 18    0                                NaN
# 19    1                                NaN
# 20    0                                NaN
# 21    0                                NaN
# 22    0                                NaN
# 23    0                                NaN
# 24    0                                NaN
# 25    0                                NaN
# 26    0                                NaN
# 27    0                                NaN
# 28    0                                NaN
# 29    0                                NaN
# 30    0                                NaN
# 31    0                                NaN
# 32    0                                NaN
# 33    0                                NaN
# 34    0                                NaN
# 35    0                                NaN
# 36    0                                NaN
# 37    0                                NaN
# 38    0                                NaN
# 39    0                                NaN
# 40    0                                NaN
# 41    1                                NaN
# 42    0                                NaN
# 43    3                                NaN
# 44    0                                NaN
# 45    2                                NaN
# 46    0                                NaN
# 47    0                                NaN
# 48    0  it seems two legs are touched, 03
# 49    0                                NaN
# 50    0                                NaN
# 51    0                                NaN
# 52    0                                NaN
# 53    0                                NaN
# 54    0                                NaN
# 55    0                                NaN
# 56    0                                NaN

# %%
J_raw_df
# Out:
#           sub_ID  first_rate second_rate  \
# 0   sub_01_EP_W2         0.0        Good
# 1   sub_02_EP_W2         1.0        Good
# 2   sub_03_EP_W2         2.0        Good
# 3   sub_04_EP_W2         0.0        Good
# 4   sub_05_EP_W2         3.5    Moderate
# 5   sub_06_EP_W2         0.0        Good
# 6   sub_07_EP_W2         0.0        Good
# 7   sub_08_EP_W2         0.0        Good
# 8   sub_09_EP_W2         0.5        Good
# 9   sub_10_EP_W2         0.0        Good
# 10  sub_11_EP_W2         0.0        Good
# 11  sub_13_EP_W2         1.5        Good
# 12  sub_14_EP_W2         0.0        Good
# 13  sub_15_EP_W2         0.0        Good
# 14  sub_16_EP_W2         1.0        Good
# 15  sub_17_EP_W2         0.0        Good
# 16  sub_18_EP_W2         2.5        Good
# 17  sub_19_EP_W2         2.5        Good
# 18  sub_20_EP_W2         2.0        Good
# 19  sub_23_EP_W2         2.0        Good
# 20  sub_24_EP_W2         4.5    Moderate
# 21  sub_25_EP_W2         7.0         Bad
# 22  sub_26_EP_W2         2.0        Good
# 23  sub_27_EP_W2         2.0        Good
# 24  sub_28_EP_W2         2.0        Good
# 25  sub_29_EP_W2         0.0        Good
# 26  sub_30_EP_W2         1.5        Good
# 27  sub_31_EP_W2         0.0        Good
# 28  sub_01_EC_W2         1.5        Good
# 29  sub_02_EC_W2         8.0         Bad
# 30  sub_03_EC_W2         7.5         Bad
# 31  sub_04_EC_W2         0.0        Good
# 32  sub_05_EC_W2         8.5         Bad
# 33  sub_06_EC_W2         0.5        Good
# 34  sub_07_EC_W2         3.5    Moderate
# 35  sub_08_EC_W2         2.0        Good
# 36  sub_09_EC_W2         3.0    Moderate
# 37  sub_10_EC_W2         5.0    Moderate
# 38  sub_11_EC_W2         3.0    Moderate
# 39  sub_12_EC_W2         3.0    Moderate
# 40  sub_13_EC_W2         4.0    Moderate
# 41  sub_14_EC_W2         2.5        Good
# 42  sub_15_EC_W2         0.0        Good
# 43  sub_16_EC_W2         3.5    Moderate
# 44  sub_17_EC_W2         0.5        Good
# 45  sub_18_EC_W2         6.0    Moderate
# 46  sub_19_EC_W2         7.0         Bad
# 47  sub_23_EC_W2         3.0        Good
# 48  sub_24_EC_W2         7.5         Bad
# 49  sub_25_EC_W2         8.5         Bad
# 50  sub_26_EC_W2         8.0         Bad
# 51  sub_27_EC_W2         5.5    Moderate
# 52  sub_28_EC_W2         5.0    Moderate
# 53  sub_29_EC_W2         1.0        Good
# 54  sub_30_EC_W2         1.5        Good
# 55  sub_31_EC_W2         6.5         Bad
#
#                                        rating reason  it1  it2  it3  it4  it5  \
# 0                                Stands almost still    1    0    0    0    0
# 1                                Stands almost still    0    0    0    0    0
# 2                      Stands still most of the time    1    0    0    1    0
# 3                                Stands almost still    0    0    0    0    0
# 4                               Many small movements    4    0    0    0    0
# 5                                Stands almost still    1    0    0    0    0
# 6                                Stands almost still    0    0    0    0    0
# 7                                Stands almost still    0    0    0    0    0
# 8                                Stands almost still    1    0    0    0    0
# 9                                Stands almost still    0    0    0    0    0
# 10                               Stands almost still    0    0    0    0    0
# 11     Stands almost still, only two lager movements    0    2    0    0    0
# 12                               Stands almost still    0    0    0    0    0
# 13                               Stands almost still    0    0    0    0    0
# 14      Stands almost still, only one lager movement    1    0    1    0    0
# 15                               Stands almost still    0    0    0    0    0
# 16            some small movements of the whole body    2    0    0    0    0
# 17            some small movements of the whole body    1    0    0    0    0
# 18                                sways a little bit    1    1    0    0    0
# 19                                sways a little bit    1    0    0    0    0
# 20              sways a lot, Problems to stand still    1    3    1    0    0
# 21             cannot stand without swaying severely   10   12    3    0    0
# 22                                Sways a little bit    3    1    0    0    0
# 23                                Sways a little bit    4    1    0    0    0
# 24                                Sways a little bit    2    2    0    0    0
# 25                                Stand almost still    0    0    0    0    0
# 26                               Sways al little bit    3    0    0    1    0
# 27                                Stand almost still    0    0    0    0    0
# 28         Sways a lot, Many movements with left leg    3    0    0    0    0
# 29                  Stepping down often, sways a lot    7   13    5    6    0
# 30                  Stepping down often, sways a lot    6    4    6    0    0
# 31                               Stands almost still    2    0    0    0    0
# 32                       Can barely stand on one leg   11    8   12    0    3
# 33                             Stands almost still,     4    0    0    1    0
# 34                                       Sway a lot.    6    8    3    0    0
# 35                                Sways a little bit    5    1    0    0    0
# 36                                      Sways a lot     7    2    2    0    0
# 37                  Sways a lot, Manylange Movements    9   11    0    1    0
# 38                                 Stands very shaky   13    0    0    0    0
# 39                        Sway a lot, Stepping down     2    3    2    0    0
# 40      Many balancing movements with the left leg      3    3    1    0    0
# 41                                  Sways sometimes     5    1    1    0    0
# 42                                Stand almost still    0    0    0    0    0
# 43                       Sways a lot, Stepping down     6    0    2    0    0
# 44                                Stand almost still    7    0    0    0    0
# 45                       Sways a lot, Stepping down     7    4    4    0    0
# 46                                 Stands very shaky    7    4    1    1    0
# 47      Stands almost still but stepping down often     5    0    1    0    0
# 48   Stepping down often, Sways stromg the hole time    5   10    6    0    0
# 49                   can¬¥t barely stand on one foot   10    9    4    0    4
# 50                   can¬¥t barely stand on one foot   11   10    6    4    0
# 51   Stepping down often but stands relatively still    9    1    6    0    0
# 52                      makes a few small movements     5    3    0    3    0
# 53  Stands almost still, only a few small movements     6    0    0    0    0
# 54  Stands still the most time, stepping down often     8    0    6    0    0
# 55                   can¬¥t barely stand on one foot   12    5    8    0    0
#
#     other comments
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 36             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
# 41             NaN
# 42             NaN
# 43             NaN
# 44             NaN
# 45             NaN
# 46             NaN
# 47             NaN
# 48             NaN
# 49             NaN
# 50             NaN
# 51             NaN
# 52             NaN
# 53             NaN
# 54             NaN
# 55             NaN

# %% [markdown]
# # Processing data

# %%
A_df = A_raw_df.copy()
J_df = J_raw_df.copy()
E_df = E_raw_df.copy()

# %%
### Sort the data according to their ID
J_sort_df = J_df.sort_values('sub_ID')
A_sort_df = A_df.sort_values('sub_ID')
E_sort_df = E_df.sort_values('sub_ID')

# %%
### Only keep the results which have been rated by every assessors
J_compared_df = J_sort_df[(J_sort_df['sub_ID'].isin(A_sort_df['sub_ID']))].reset_index(drop=True)
A_compared_df = A_sort_df[(A_sort_df['sub_ID'].isin(J_sort_df['sub_ID']))].reset_index(drop=True)
E_compared_df = E_sort_df[(E_sort_df['sub_ID'].isin(A_compared_df['sub_ID']))].reset_index(drop=True)

# %%
### check if there is incorresponding comparison index
(J_compared_df['sub_ID'].isin(A_compared_df['sub_ID']) == 0).sum() + (E_compared_df['sub_ID'].isin(J_compared_df['sub_ID']) == 0).sum()
# Out:
# 0

# %%
### Calculate the total BESS 
J_compared_df['total_BESS'] = J_compared_df['it1'] + J_compared_df['it2'] + J_compared_df['it3'] + J_compared_df['it4'] + J_compared_df['it5']
A_compared_df['total_BESS'] = A_compared_df['it1'] + A_compared_df['it2'] + A_compared_df['it3'] + A_compared_df['it4'] + A_compared_df['it5']
E_compared_df['total_BESS'] = E_compared_df['it1'] + E_compared_df['it2'] + E_compared_df['it3'] + E_compared_df['it4'] + E_compared_df['it5']

# %%
J_compared_df = J_compared_df.fillna(0)
A_compared_df = A_compared_df.fillna(0)
E_compared_df = E_compared_df.fillna(0)

# %%
E_compared_df
# Out:
#           sub_ID  first_rate second_rate  \
# 0   sub_01_EC_W2         2.5        Good
# 1   sub_01_EP_W2         0.5        Good
# 2   sub_02_EC_W2         8.0         Bad
# 3   sub_02_EP_W2         1.0        Good
# 4   sub_03_EC_W2         7.5         Bad
# 5   sub_03_EP_W2         0.0        Good
# 6   sub_04_EC_W2         0.0        Good
# 7   sub_04_EP_W2         0.0        Good
# 8   sub_05_EC_W2        10.0         Bad
# 9   sub_05_EP_W2         2.5    Moderate
# 10  sub_06_EC_W2         0.5        Good
# 11  sub_06_EP_W2         0.0        Good
# 12  sub_07_EC_W2         6.5    Moderate
# 13  sub_07_EP_W2         0.0        Good
# 14  sub_08_EC_W2         0.5        Good
# 15  sub_08_EP_W2         0.0        Good
# 16  sub_09_EC_W2         5.0    Moderate
# 17  sub_09_EP_W2         0.5        Good
# 18  sub_10_EC_W2         6.0    Moderate
# 19  sub_10_EP_W2         0.0        Good
# 20  sub_11_EC_W2         1.5        Good
# 21  sub_11_EP_W2         0.0        Good
# 22  sub_12_EC_W2         3.5    Moderate
# 23  sub_13_EC_W2         4.0    Moderate
# 24  sub_13_EP_W2         0.5        Good
# 25  sub_14_EC_W2         1.0        Good
# 26  sub_14_EP_W2         0.0        Good
# 27  sub_15_EC_W2         1.0        Good
# 28  sub_15_EP_W2         0.0        Good
# 29  sub_16_EC_W2         0.5        Good
# 30  sub_16_EP_W2         1.0        Good
# 31  sub_17_EC_W2         0.5        Good
# 32  sub_17_EP_W2         0.0        Good
# 33  sub_18_EC_W2         7.0         Bad
# 34  sub_18_EP_W2         0.0        Good
# 35  sub_19_EC_W2         6.5         Bad
# 36  sub_19_EP_W2         0.0        Good
# 37  sub_23_EC_W2         2.5    Moderate
# 38  sub_23_EP_W2         0.5        Good
# 39  sub_24_EC_W2         8.0         Bad
# 40  sub_24_EP_W2         1.5        Good
# 41  sub_25_EC_W2         8.5         Bad
# 42  sub_25_EP_W2         7.5         Bad
# 43  sub_26_EC_W2         8.0         Bad
# 44  sub_26_EP_W2         0.5        Good
# 45  sub_27_EC_W2         5.0    Moderate
# 46  sub_27_EP_W2         0.5        Good
# 47  sub_28_EC_W2         0.5        Good
# 48  sub_28_EP_W2         0.0        Good
# 49  sub_29_EC_W2         0.5        Good
# 50  sub_29_EP_W2         0.0        Good
# 51  sub_30_EC_W2         3.5    Moderate
# 52  sub_30_EP_W2         0.5        Good
# 53  sub_31_EC_W2         8.5         Bad
# 54  sub_31_EP_W2         0.0        Good
#
#                                         rating reason  it1  it2  it3  it4  \
# 0                          2 to 3 balancing movements    0    1    0    0
# 1                                        did not move    0    0    0    0
# 2                    foot on the ground several times    0    2    5    1
# 3                                                good    0    0    0    0
# 4                             touched several times.     2    2    4    0
# 5                                        did not move    0    0    0    0
# 6                                        did not move    0    0    0    0
# 7                                        did not move    0    0    0    0
# 8                      touched a lot, shaking a lot.     0    6    7    9
# 9                                   shaking, but fine    0    0    0    0
# 10                                               good    0    0    0    0
# 11                                               good    0    0    0    0
# 12                             several moving, but ok    0    4    3    0
# 13                                         no moving     0    0    0    0
# 14                                  barely no moving     0    1    0    0
# 15                                         no moving     0    0    0    0
# 16                    touched a bit, lots of shaking     0    1    2    0
# 17                                     a lil shaking     0    0    0    0
# 18  lots of shaking, but feet never touches the gr...    0    8    0    1
# 19                                               good    0    0    0    0
# 20                                     good, shaking     2    0    0    0
# 21                                             good,     0    0    0    0
# 22                                    several touches    0    1    2    0
# 23                          several touches, shaking     0    5    1    0
# 24                                              good     0    2    0    0
# 25                     good, touched the ground once     0    1    1    0
# 26                                              good     0    0    0    0
# 27                                    good, shaking      0    2    0    0
# 28                                              good,    0    0    0    0
# 29                                               good    0    0    2    0
# 30                            good, but touched once     0    0    1    0
# 31                                               good    0    1    0    0
# 32                                          very good    0    0    0    0
# 33  touched several times, lots of shaking and bal...    2    3    4    0
# 34                                              good     0    0    0    0
# 35  raising leg shaking a lot, standing leg shakin...    1    7    1    1
# 36                                               good    0    0    0    0
# 37                                 good, but touched     0    0    3    0
# 38                                               good    0    0    0    0
# 39  switched feet at the beginning, and touched th...    2    4    6    0
# 40                                                ok     0    3    1    0
# 41                                   not good at all     5    8    4    0
# 42         for someone whose eyes are open, it's bad     3   10    2    0
# 43                     several touches and balancing     4    6    5    6
# 44                                                 ok    0    1    0    0
# 45                                    ok but touched     0    0    4    0
# 46                                              good     0    0    0    0
# 47                                              good     0    4    0    3
# 48                           good, barely no shaking     0    0    0    0
# 49                      barely no balancing movement     1    3    0    0
# 50                                               good    0    0    0    0
# 51                                   could be better     1    0    5    0
# 52                                              good     0    0    1    0
# 53                                          not good     5    3    1    6
# 54                                              good     0    0    0    0
#
#     it5                     other comments  total_BESS
# 0     0                                  0           1
# 1     0                                  0           0
# 2     0                                  0           8
# 3     0                                  0           0
# 4     0                                  0           8
# 5     0                                  0           0
# 6     0                                  0           0
# 7     0                                  0           0
# 8     0                                  0          22
# 9     0                                  `           0
# 10    0                                  0           0
# 11    0                                  0           0
# 12    0                                  0           7
# 13    0                                  0           0
# 14    0                                  0           1
# 15    0                                  0           0
# 16    0                                  0           3
# 17    0                                  0           0
# 18    1                                  0          10
# 19    0                                  0           0
# 20    0                                  0           2
# 21    0                                  0           0
# 22    0                                  0           3
# 23    0                                  0           6
# 24    0                                  0           2
# 25    0                                  0           2
# 26    0                                  0           0
# 27    0                                  0           2
# 28    0                                  0           0
# 29    0                                  0           2
# 30    0                                  0           1
# 31    0                                  0           1
# 32    0                                  0           0
# 33    0                                  0           9
# 34    0                                  0           0
# 35    0                                  0          10
# 36    0                                  0           0
# 37    0                                  0           3
# 38    0                                  0           0
# 39    1                                  0          13
# 40    0                                  0           4
# 41    3                                  0          20
# 42    0                                  0          15
# 43    2                                  0          23
# 44    0                                  0           1
# 45    0                                  0           4
# 46    0  it seems two legs are touched, 03           0
# 47    0                                  0           7
# 48    0                                  0           0
# 49    0                                  0           4
# 50    0                                  0           0
# 51    0                                  0           6
# 52    0                                  0           1
# 53    0                                  0          15
# 54    0                                  0           0

# %% [markdown]
# # Result

# %% [markdown]
# ## How human assess the performance of OLST?

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
rate_reason = []
for i in A_compared_df['rating reason']:
    rate_reason.append(i)
for i in J_compared_df['rating reason']:
    rate_reason.append(i)
for i in E_compared_df['rating reason']:
    rate_reason.append(i)

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["almost", "lot", "wine", "flavor", "flavors"])

# %%
# Create and generate a word cloud image:
#wordcloud = WordCloud(background_color="white", stopwords=stopwords).generate(text)

# Display the generated image:
#plt.figure(figsize=(10,10))
#plt.imshow(wordcloud, interpolation='bilinear')
#plt.axis("off")
#plt.show()

# %% [markdown]
# ## What is the cut off value for each level?

# %%
A_level = np.array(A_compared_df['second_rate'])
J_level = np.array(J_compared_df['second_rate'])
E_level = np.array(E_compared_df['second_rate'])
sub_ID = np.array(J_compared_df['sub_ID'])

# %%
classification_df = pd.DataFrame({
    "sub_ID":sub_ID,
    "J_rate":J_level,
    "A_rate":A_level,
    "E_rate":E_level
    
})

# %%
overall_subjective_assessment = np.array((J_compared_df['first_rate'] + A_compared_df['first_rate'] + E_compared_df['first_rate'])/3)
overall_BESS_assessment = np.array((J_compared_df['total_BESS'] + A_compared_df['total_BESS'] + E_compared_df['total_BESS'])/3)

# %%
classification_df['overall_subjective_assessment'] = overall_subjective_assessment
classification_df['overall_BESS_assessment'] = overall_BESS_assessment

# %%
import seaborn as sns

# %%
overall_level = []
for i in range(classification_df.shape[0]):
    if classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["A_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["A_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["A_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
        
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["A_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["A_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["A_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")

    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["A_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["A_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["A_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
        
    else:
        overall_level.append("Moderate")

# %%
classification_df["overall_rate"] = overall_level

# %%
BESS_Good_mean = classification_df.groupby("overall_rate").mean()["overall_BESS_assessment"].Good
BESS_Mod_mean = classification_df.groupby("overall_rate").mean()["overall_BESS_assessment"].Moderate
BESS_Bad_mean = classification_df.groupby("overall_rate").mean()["overall_BESS_assessment"].Bad

BESS_Good_std = classification_df.groupby("overall_rate").std()["overall_BESS_assessment"].Good
BESS_Mod_std = classification_df.groupby("overall_rate").std()["overall_BESS_assessment"].Moderate
BESS_Bad_std = classification_df.groupby("overall_rate").std()["overall_BESS_assessment"].Bad

# %%
Good_low_cut = 0
Good_high_cut = (BESS_Good_mean+BESS_Good_std)
Mod_low_cut = (BESS_Mod_mean - BESS_Mod_std)
Mod_high_cut = (BESS_Mod_mean+BESS_Mod_std)
Bad_low_cut = (BESS_Bad_mean-BESS_Bad_std)
Bad_high_cut = (BESS_Bad_mean+BESS_Bad_std)

# %%
x1, y1 = [-1, 10], [0, 0]
x2, y2 = [-1, 10], [Good_high_cut, Good_high_cut]
x3, y3 = [-1, 10], [Mod_low_cut, Mod_low_cut]
x4, y4 = [-1, 10], [Mod_high_cut, Mod_high_cut]
x5, y5 = [-1, 10], [Bad_low_cut, Bad_low_cut]
x6, y6 = [-1, 10], [Bad_high_cut, Bad_high_cut]


#sns.scatterplot(data = classification_df, x = "overall_subjective_assessment", y = "overall_BESS_assessment", hue = "overall_rate", hue_order = ["Good", "Moderate", "Bad"], palette = ["green", "yellow", "red"])
sns.lmplot(data = classification_df, x = "overall_subjective_assessment", y = "overall_BESS_assessment", hue= "overall_rate", hue_order = ["Good", "Moderate", "Bad"], palette = ["green", "yellow", "red"], fit_reg=False)
sns.regplot(data = classification_df, x = "overall_subjective_assessment", y = "overall_BESS_assessment", scatter=False)


plt.plot(x2, y2, color = "green" )
plt.plot(x3, y3, color = "yellow" )
plt.plot(x4, y4, color = "yellow" )
plt.plot(x5, y5, color = "red")
plt.xlim(-0.5, 10)
plt.ylim(-0.5, 25)
# Out:
# (-0.5, 25.0)

# %%
### Pearson correlation coefficient
np.corrcoef(overall_subjective_assessment, overall_BESS_assessment)
# Out:
# array([[1.        , 0.94355537],
#        [0.94355537, 1.        ]])

# %%
import scipy.stats

# %%
scipy.stats.pearsonr(overall_subjective_assessment, overall_BESS_assessment)
# Out:
# (0.9435553660677645, 4.2446050964034015e-27)

# %%
scipy.stats.spearmanr(overall_subjective_assessment, overall_BESS_assessment)
# Out:
# SpearmanrResult(correlation=0.934163366390863, pvalue=2.226620796146258e-25)

# %%
classification_df.groupby("overall_rate").mean()
# Out:
#               overall_subjective_assessment  overall_BESS_assessment
# overall_rate
# Bad                                7.388889                17.777778
# Good                               0.750000                 1.774510
# Moderate                           4.222222                 8.416667

# %%
classification_df.groupby("overall_rate").std()
# Out:
#               overall_subjective_assessment  overall_BESS_assessment
# overall_rate
# Bad                                0.606676                 4.870546
# Good                               0.716860                 2.270764
# Moderate                           1.299443                 3.903184

# %%
Bad_rate = classification_df['overall_subjective_assessment'][classification_df['overall_rate'] == "Bad"]
Moderate_rate = classification_df['overall_subjective_assessment'][classification_df['overall_rate'] == "Moderate"]
Good_rate = classification_df['overall_subjective_assessment'][classification_df['overall_rate'] == "Good"]

# %%
k = len(classification_df['overall_rate'].unique())
N = len(classification_df['overall_rate'])

print("df({}, {})".format(k, N))
# Out:
# df(3, 55)

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(Bad_rate, Moderate_rate, Good_rate)
print(round(fvalue, 2), "ANOVA p value: ", format(pvalue, '.8f'))
# Out:
# 239.44 ANOVA p value:  0.00000000

# %%
print("t-test (B-M) p value: ", format((stats.ttest_ind(Bad_rate, Moderate_rate)).pvalue, '.8f'))
# Out:
# t-test (B-M) p value:  0.00000190

# %%
print("t-test (B-M) p value: ", format((stats.ttest_ind(Good_rate, Moderate_rate)).pvalue, '.8f'))
# Out:
# t-test (B-M) p value:  0.00000000

# %%
print("t-test (B-M) p value: ", format((stats.ttest_ind(Bad_rate, Good_rate)).pvalue, '.8f'))
# Out:
# t-test (B-M) p value:  0.00000000

# %%
k = len(classification_df['overall_rate'].unique())-1
N = len(classification_df['overall_rate'])-1

print("df({}, {})".format(k, N))
# Out:
# df(2, 54)

# %%
Bad_rate = classification_df['overall_BESS_assessment'][classification_df['overall_rate'] == "Bad"]
Moderate_rate = classification_df['overall_BESS_assessment'][classification_df['overall_rate'] == "Moderate"]
Good_rate = classification_df['overall_BESS_assessment'][classification_df['overall_rate'] == "Good"]

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(Bad_rate, Moderate_rate, Good_rate)
print("F({}, {}) = {}, p = {}".format(k,N,round(fvalue, 2), format(pvalue, '.8f')))
# Out:
# F(2, 54) = 94.84, p = 0.00000000

# %%
stats.ttest_ind(Bad_rate, Moderate_rate)
t = stats.ttest_ind(Bad_rate, Moderate_rate).statistic
p = stats.ttest_ind(Bad_rate, Moderate_rate).pvalue

print("t = {}, p = {}".format(t, p))
# Out:
# t = 4.895001013595662, p = 0.00010055314197119708

# %%
stats.ttest_ind(Good_rate, Moderate_rate)
t = stats.ttest_ind(Good_rate, Moderate_rate).statistic
p = stats.ttest_ind(Good_rate, Moderate_rate).pvalue

print("t = {}, p = {}".format(t, round(p, 6)))
# Out:
# t = -7.139916865369371, p = 0.0

# %%
stats.ttest_ind(Good_rate, Bad_rate)
t = stats.ttest_ind(Good_rate, Bad_rate).statistic
p = stats.ttest_ind(Good_rate, Bad_rate).pvalue

print("t = {}, p = {}".format(t, round(p, 5)))
# Out:
# t = -14.408318395386848, p = 0.0

# %% [markdown]
# ## Can we build an automated BESS scoring system?
# *	What is the difference in the frequency of error between human assessment and system assessment during the task according to BESS?
# *	What is the correlation between each assessment?

# %% [markdown]
# ### What is the difference in the frequency of error between human assessment and system assessment during the task according to BESS?

# %%
lifting_foot_count = (J_compared_df['it1'].sum() + A_compared_df['it1'].sum() + E_compared_df['it1'].sum())
moving_hip_count = (J_compared_df['it2'].sum() + A_compared_df['it2'].sum() + E_compared_df['it2'].sum())
stepping_count = (J_compared_df['it3'].sum() + A_compared_df['it3'].sum() + E_compared_df['it3'].sum())
lifting_hand_count = (J_compared_df['it4'].sum() + A_compared_df['it4'].sum()+ E_compared_df['it4'].sum())
remain_5s_count = (J_compared_df['it5'].sum() + A_compared_df['it5'].sum()+ E_compared_df['it5'].sum())

# %%
classification_df
# Out:
#           sub_ID    J_rate    A_rate    E_rate  overall_subjective_assessment  \
# 0   sub_01_EC_W2      Good      Good      Good                       2.333333
# 1   sub_01_EP_W2      Good      Good      Good                       0.333333
# 2   sub_02_EC_W2       Bad       Bad       Bad                       8.000000
# 3   sub_02_EP_W2      Good      Good      Good                       0.833333
# 4   sub_03_EC_W2       Bad  Moderate       Bad                       6.666667
# 5   sub_03_EP_W2      Good      Good      Good                       1.000000
# 6   sub_04_EC_W2      Good      Good      Good                       0.000000
# 7   sub_04_EP_W2      Good      Good      Good                       0.000000
# 8   sub_05_EC_W2       Bad  Moderate       Bad                       7.333333
# 9   sub_05_EP_W2  Moderate      Good  Moderate                       2.000000
# 10  sub_06_EC_W2      Good      Good      Good                       0.500000
# 11  sub_06_EP_W2      Good      Good      Good                       0.166667
# 12  sub_07_EC_W2  Moderate  Moderate  Moderate                       5.333333
# 13  sub_07_EP_W2      Good      Good      Good                       0.166667
# 14  sub_08_EC_W2      Good      Good      Good                       0.833333
# 15  sub_08_EP_W2      Good      Good      Good                       0.000000
# 16  sub_09_EC_W2  Moderate  Moderate  Moderate                       3.833333
# 17  sub_09_EP_W2      Good      Good      Good                       0.666667
# 18  sub_10_EC_W2  Moderate  Moderate  Moderate                       5.833333
# 19  sub_10_EP_W2      Good      Good      Good                       0.166667
# 20  sub_11_EC_W2  Moderate      Good      Good                       2.000000
# 21  sub_11_EP_W2      Good      Good      Good                       0.000000
# 22  sub_12_EC_W2  Moderate  Moderate  Moderate                       3.666667
# 23  sub_13_EC_W2  Moderate  Moderate  Moderate                       4.333333
# 24  sub_13_EP_W2      Good      Good      Good                       0.833333
# 25  sub_14_EC_W2      Good      Good      Good                       1.666667
# 26  sub_14_EP_W2      Good      Good      Good                       0.000000
# 27  sub_15_EC_W2      Good      Good      Good                       1.333333
# 28  sub_15_EP_W2      Good      Good      Good                       0.000000
# 29  sub_16_EC_W2  Moderate  Moderate      Good                       2.666667
# 30  sub_16_EP_W2      Good      Good      Good                       1.000000
# 31  sub_17_EC_W2      Good      Good      Good                       0.333333
# 32  sub_17_EP_W2      Good      Good      Good                       0.000000
# 33  sub_18_EC_W2  Moderate  Moderate       Bad                       6.500000
# 34  sub_18_EP_W2      Good      Good      Good                       0.833333
# 35  sub_19_EC_W2       Bad  Moderate       Bad                       6.666667
# 36  sub_19_EP_W2      Good      Good      Good                       1.166667
# 37  sub_23_EC_W2      Good  Moderate  Moderate                       3.500000
# 38  sub_23_EP_W2      Good      Good      Good                       0.833333
# 39  sub_24_EC_W2       Bad       Bad       Bad                       7.500000
# 40  sub_24_EP_W2  Moderate  Moderate      Good                       3.666667
# 41  sub_25_EC_W2       Bad       Bad       Bad                       8.500000
# 42  sub_25_EP_W2       Bad  Moderate       Bad                       7.000000
# 43  sub_26_EC_W2       Bad  Moderate       Bad                       7.166667
# 44  sub_26_EP_W2      Good      Good      Good                       1.166667
# 45  sub_27_EC_W2  Moderate  Moderate  Moderate                       5.166667
# 46  sub_27_EP_W2      Good      Good      Good                       0.833333
# 47  sub_28_EC_W2  Moderate      Good      Good                       2.833333
# 48  sub_28_EP_W2      Good      Good      Good                       0.666667
# 49  sub_29_EC_W2      Good      Good      Good                       1.166667
# 50  sub_29_EP_W2      Good      Good      Good                       0.000000
# 51  sub_30_EC_W2      Good       Bad  Moderate                       4.166667
# 52  sub_30_EP_W2      Good      Good      Good                       1.500000
# 53  sub_31_EC_W2       Bad       Bad       Bad                       7.666667
# 54  sub_31_EP_W2      Good      Good      Good                       0.333333
#
#     overall_BESS_assessment overall_rate
# 0                  2.333333         Good
# 1                  0.333333         Good
# 2                 17.000000          Bad
# 3                  0.000000         Good
# 4                 10.000000          Bad
# 5                  1.666667         Good
# 6                  0.666667         Good
# 7                  0.000000         Good
# 8                 21.333333          Bad
# 9                  2.666667     Moderate
# 10                 2.333333         Good
# 11                 0.666667         Good
# 12                11.666667     Moderate
# 13                 0.000000         Good
# 14                 2.666667         Good
# 15                 0.000000         Good
# 16                 6.666667     Moderate
# 17                 0.333333         Good
# 18                15.333333     Moderate
# 19                 0.000000         Good
# 20                 8.333333         Good
# 21                 0.000000         Good
# 22                 5.000000     Moderate
# 23                 7.666667     Moderate
# 24                 1.666667         Good
# 25                 3.666667         Good
# 26                 0.000000         Good
# 27                 4.000000         Good
# 28                 0.000000         Good
# 29                 5.333333     Moderate
# 30                 1.333333         Good
# 31                 2.666667         Good
# 32                 0.000000         Good
# 33                12.000000     Moderate
# 34                 0.666667         Good
# 35                11.000000          Bad
# 36                 0.666667         Good
# 37                 6.000000     Moderate
# 38                 0.333333         Good
# 39                16.000000          Bad
# 40                 5.333333     Moderate
# 41                22.333333          Bad
# 42                18.666667          Bad
# 43                24.333333          Bad
# 44                 3.333333         Good
# 45                12.666667     Moderate
# 46                 2.000000         Good
# 47                 8.666667         Good
# 48                 4.000000         Good
# 49                 5.666667         Good
# 50                 0.000000         Good
# 51                10.666667     Moderate
# 52                 2.333333         Good
# 53                19.333333          Bad
# 54                 0.000000         Good

# %%
overall_level = []
for i in range(classification_df.shape[0]):
    if classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["A_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["A_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["A_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
    elif classification_df.iloc[i]["J_rate"] == "Good" and classification_df.iloc[i]["E_rate"] == "Good":
        overall_level.append("Good")
        
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["A_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["A_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["A_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")
    elif classification_df.iloc[i]["J_rate"] == "Moderate" and classification_df.iloc[i]["E_rate"] == "Moderate":
        overall_level.append("Moderate")

    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["A_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["A_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["A_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
    elif classification_df.iloc[i]["J_rate"] == "Bad" and classification_df.iloc[i]["E_rate"] == "Bad":
        overall_level.append("Bad")
        
    else:
        overall_level.append("Moderate")

overall_it1 = (J_compared_df["it1"] + A_compared_df["it1"] + E_compared_df["it1"])/3
overall_it2 = (J_compared_df["it2"] + A_compared_df["it2"] + E_compared_df["it2"])/3
overall_it3 = (J_compared_df["it3"] + A_compared_df["it3"] + E_compared_df["it3"])/3
overall_it4 = (J_compared_df["it4"] + A_compared_df["it4"] + E_compared_df["it4"])/3
overall_it5 = (J_compared_df["it5"] + A_compared_df["it5"] + E_compared_df["it5"])/3

# %%
new_df = pd.DataFrame({
    "overall_level":overall_level,
    "overall_it1":overall_it1,
    "overall_it2":overall_it2,
    "overall_it3":overall_it3,
    "overall_it4":overall_it4,
    "overall_it5":overall_it5
})

# %%
classification_df["overall_it1"] = overall_it1
classification_df["overall_it2"] = overall_it2
classification_df["overall_it3"] = overall_it3
classification_df["overall_it4"] = overall_it4
classification_df["overall_it5"] = overall_it5
classification_df["overall_level"] = overall_level

# %%
it1_df = new_df[["overall_level", "overall_it1"]]
it1_df.columns= ["overall_level", "BESS"]
it1_df['BESS_label'] = ["it1"]*new_df.shape[0]

it2_df = new_df[["overall_level", "overall_it2"]]
it2_df.columns= ["overall_level", "BESS"]
it2_df['BESS_label'] = ["it2"]*new_df.shape[0]

it3_df = new_df[["overall_level", "overall_it3"]]
it3_df.columns= ["overall_level", "BESS"]
it3_df['BESS_label'] = ["it3"]*new_df.shape[0]

it4_df = new_df[["overall_level", "overall_it4"]]
it4_df.columns= ["overall_level", "BESS"]
it4_df['BESS_label'] = ["it4"]*new_df.shape[0]

it5_df = new_df[["overall_level", "overall_it5"]]
it5_df.columns= ["overall_level", "BESS"]
it5_df['BESS_label'] = ["it5"]*new_df.shape[0]

barplot_df_human = pd.concat([it1_df, it2_df, it3_df, it4_df, it5_df])
# Out:
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
b = sns.barplot(x="BESS_label", y="BESS", hue = "overall_level",data = barplot_df_human, hue_order = ["Good", "Moderate", "Bad"], palette = ["green", "yellow", "red"]);
b.set_xticklabels(["Lifting foot", "Moving hip", "Stepping", "Lifting hand", "Out pos >5"])
plt.ylim(0, 8)
# Out:
# (0.0, 8.0)

# %%
plt.bar([1, 2, 3, 4, 5], [lifting_foot_count, moving_hip_count, stepping_count, lifting_hand_count, remain_5s_count])
plt.xticks([1, 2, 3, 4, 5], ['lifting_foot_count', 'moving_hip_count', 'stepping_count', 'lifting_hand_count', 'remain_5s_count'], rotation=20)
# Out:
# ([<matplotlib.axis.XTick at 0x231828db448>,
#   <matplotlib.axis.XTick at 0x231828e99c8>,
#   <matplotlib.axis.XTick at 0x231828e9f48>,
#   <matplotlib.axis.XTick at 0x23182893848>,
#   <matplotlib.axis.XTick at 0x231828842c8>],
#  [Text(1, 0, 'lifting_foot_count'),
#   Text(2, 0, 'moving_hip_count'),
#   Text(3, 0, 'stepping_count'),
#   Text(4, 0, 'lifting_hand_count'),
#   Text(5, 0, 'remain_5s_count')])

# %%
### Barplot (for each level) (system)

# %%
import pandas as pd
import numpy as np
import os
### Direct to the correct folder
path = 'C:/Users/a1003/OneDrive/桌面/Thesis/data/OLBT/sub1to31'
filenames = os.listdir(path)   ### List the files name in the folder
sub_id = []                    ### Initialize the subject name list
value_list = []               ### Initialzie the value list

### Organize the information into different list and then integrate them together as a dataframe
for sub in filenames:
    curr_file = path + '/' + sub
    curr_csv = pd.read_csv(curr_file)
    value = list(curr_csv.loc[0])
    value_list.append(value)
    ID = str(curr_csv["sub_ID"][0]) ### -25: sub0?, -4: remove .csv
    sub_id.append(ID)
### Create the correct columns name
col_names = list(curr_csv.columns)
all_col_names = ["sub_ID"] + col_names
### Create the correct metrix which is going to be convert to dataframe
all_list = []
for i in range(len(sub_id)):
    v = [(sub_id[i])] + value_list[i]
    all_list.append(v)
    
### Use the list and metrix above the create a new table
raw_df = pd.DataFrame(all_list, columns = all_col_names)
AM_df = raw_df.iloc[:, 33:]

# %%
raw_df.columns = ['sub', 'SL_fore_var_height', 'SL_heel_var_height',
       'OL_fore_var_height', 'OL_heel_var_height', 'SL_fore_mean_height',
       'SL_heel_mean_height', 'OL_fore_mean_height', 'OL_heel_mean_height',
       'SL_fore_max_height', 'SL_heel_max_height', 'OL_fore_max_height',
       'OL_heel_max_height', 'SL_var_flex', 'OL_var_flex', 'SL_mean_flex',
       'OL_mean_flex', 'SL_max_flex', 'OL_max_flex', 'SL_duration_flex',
       'OL_duration_flex', 'SL_var_abd', 'OL_var_abd', 'SL_mean_abd',
       'OL_mean_abd', 'SL_max_abd', 'OL_max_abd', 'SL_duration_abd',
       'OL_duration_abd', 'stepping_freq', 'stepping_duration', 'var_RL_dis',
       'Max_min_RL_dis', 'sub_ID', 'foot_height_count', 'angle_count',
       'stepping_count', 'hand_iliac_count', 'out_position_count', 'totel']
df = raw_df.drop(["sub_ID"], axis = 1)
SL_train_df = df[(df['sub'].isin(classification_df['sub_ID']))].reset_index(drop=True)
target = classification_df[(classification_df['sub_ID'].isin(SL_train_df['sub']))].reset_index(drop=True)
SL_target = target["overall_rate"]
SL_train_df.to_csv("SL_df.csv")
SL_target.to_csv("SL_target.csv")

# %%
Automated_system_raw_df = AM_df
Automated_sorted_df = Automated_system_raw_df.sort_values('sub_ID')
#Automated_sorted_df

Automated_compared_df = Automated_sorted_df[(Automated_sorted_df['sub_ID'].isin(classification_df['sub_ID']))].reset_index(drop=True)
sorted_df = classification_df[(classification_df['sub_ID'].isin(Automated_compared_df['sub_ID']))].reset_index(drop=True)
Automated_compared_df["labels"] = sorted_df["overall_level"]
Automated_compared_df
# Out:
#           sub_ID  foot_height_count  angle_count  stepping_count  \
# 0   sub_01_EC_W2                  0            0               0
# 1   sub_01_EP_W2                  2            0               0
# 2   sub_02_EC_W2                  0            3               5
# 3   sub_02_EP_W2                  0            0               0
# 4   sub_03_EC_W2                  5            4               5
# 5   sub_03_EP_W2                  2            0               0
# 6   sub_04_EC_W2                  2            0               0
# 7   sub_04_EP_W2                  2            0               0
# 8   sub_05_EC_W2                  3            4               6
# 9   sub_05_EP_W2                  3            0               0
# 10  sub_06_EC_W2                  3            0               0
# 11  sub_06_EP_W2                  2            0               0
# 12  sub_07_EC_W2                  0            2               3
# 13  sub_07_EP_W2                  1            0               0
# 14  sub_08_EC_W2                  1            0               0
# 15  sub_08_EP_W2                  0            0               0
# 16  sub_09_EC_W2                  3            3               2
# 17  sub_09_EP_W2                  1            0               0
# 18  sub_10_EC_W2                  2            6               0
# 19  sub_10_EP_W2                  1            0               0
# 20  sub_11_EC_W2                  4            2               0
# 21  sub_11_EP_W2                  2            0               0
# 22  sub_12_EC_W2                  0            0               2
# 23  sub_13_EC_W2                  0            2               1
# 24  sub_13_EP_W2                  1            0               0
# 25  sub_14_EC_W2                  1            0               1
# 26  sub_14_EP_W2                  0            0               0
# 27  sub_15_EC_W2                  1            2               0
# 28  sub_15_EP_W2                  2            0               0
# 29  sub_16_EC_W2                  1            0               1
# 30  sub_16_EP_W2                  1            0               1
# 31  sub_17_EC_W2                  3            0               0
# 32  sub_17_EP_W2                  0            0               0
# 33  sub_18_EC_W2                  3            5               4
# 34  sub_19_EC_W2                  0            2               1
# 35  sub_19_EP_W2                  0            0               0
# 36  sub_23_EC_W2                  4            0               2
# 37  sub_23_EP_W2                  2            0               0
# 38  sub_24_EC_W2                  2           11               8
# 39  sub_24_EP_W2                  0            3               0
# 40  sub_25_EC_W2                  2            8               8
# 41  sub_25_EP_W2                  1            5               2
# 42  sub_26_EC_W2                  5            9               6
# 43  sub_26_EP_W2                  2            0               0
# 44  sub_27_EC_W2                  4            6               3
# 45  sub_29_EC_W2                  2            2               1
# 46  sub_29_EP_W2                  1            0               0
# 47  sub_30_EC_W2                  2            8               4
# 48  sub_30_EP_W2                  1            0               0
#
#     hand_iliac_count  out_position_count  totel    labels
# 0                  4                   0      4      Good
# 1                  1                   0      3      Good
# 2                  1                   0      9       Bad
# 3                  0                   0      0      Good
# 4                  0                   0     14       Bad
# 5                  1                   0      3      Good
# 6                  6                   0      8      Good
# 7                  0                   0      2      Good
# 8                  3                   0     16       Bad
# 9                  3                   0      6  Moderate
# 10                 1                   0      4      Good
# 11                 2                   0      4      Good
# 12                 0                   0      5  Moderate
# 13                 0                   0      1      Good
# 14                 8                   0      9      Good
# 15                 0                   0      0      Good
# 16                 0                   0      8  Moderate
# 17                 0                   0      1      Good
# 18                 2                   0     10  Moderate
# 19                 0                   0      1      Good
# 20                 0                   0      6      Good
# 21                 0                   0      2      Good
# 22                 1                   0      3  Moderate
# 23                 0                   0      3  Moderate
# 24                 0                   0      1      Good
# 25                 0                   0      2      Good
# 26                 1                   0      1      Good
# 27                 1                   0      4      Good
# 28                 1                   0      3      Good
# 29                 0                   0      2  Moderate
# 30                 0                   0      2      Good
# 31                 0                   0      3      Good
# 32                 0                   0      0      Good
# 33                 0                   0     12  Moderate
# 34                 2                   0      5       Bad
# 35                 1                   0      1      Good
# 36                 0                   0      6  Moderate
# 37                 0                   0      2      Good
# 38                 0                   0     21       Bad
# 39                 1                   0      4  Moderate
# 40                 0                   0     18       Bad
# 41                 0                   0      8       Bad
# 42                 4                   0     24       Bad
# 43                 0                   0      2      Good
# 44                 0                   0     13  Moderate
# 45                 0                   0      5      Good
# 46                 0                   0      1      Good
# 47                 1                   0     15  Moderate
# 48                 1                   0      2      Good

# %%
#barplot_df_system = Automated_sorted_df[(Automated_sorted_df['sub_ID'].isin(predicted_df['Sub']))].reset_index(drop=True)

# %%
barplot_df_system = Automated_compared_df
#barplot_df_system

# %%
matlab_assessing_df = barplot_df_system

# %%
it1_df = matlab_assessing_df[["labels", "foot_height_count"]]
it1_df.columns= ["overall_level", "BESS"]
it1_df['BESS_label'] = ["it1"]*matlab_assessing_df.shape[0]

it2_df = matlab_assessing_df[["labels", "angle_count"]]
it2_df.columns= ["overall_level", "BESS"]
it2_df['BESS_label'] = ["it2"]*matlab_assessing_df.shape[0]

it3_df = matlab_assessing_df[["labels", "stepping_count"]]
it3_df.columns= ["overall_level", "BESS"]
it3_df['BESS_label'] = ["it3"]*matlab_assessing_df.shape[0]

it4_df = matlab_assessing_df[["labels", "hand_iliac_count"]]
it4_df.columns= ["overall_level", "BESS"]
it4_df['BESS_label'] = ["it4"]*matlab_assessing_df.shape[0]

it5_df = matlab_assessing_df[["labels", "out_position_count"]]
it5_df.columns= ["overall_level", "BESS"]
it5_df['BESS_label'] = ["it5"]*matlab_assessing_df.shape[0]

barplot_df_system = pd.concat([it1_df, it2_df, it3_df, it4_df, it5_df])
# Out:
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
bad_df_human = barplot_df_human[(barplot_df_human["overall_level"]=="Bad")]
bad_df_human[bad_df_human["BESS_label"]=="it1"]
# Out:
#    overall_level      BESS BESS_label
# 2            Bad  2.666667        it1
# 4            Bad  2.666667        it1
# 8            Bad  6.000000        it1
# 35           Bad  2.666667        it1
# 39           Bad  2.666667        it1
# 41           Bad  6.666667        it1
# 42           Bad  6.666667        it1
# 43           Bad  8.000000        it1
# 53           Bad  8.666667        it1

# %%
bad_df = barplot_df_system[(barplot_df_system["overall_level"]=="Bad")]
bad_df[bad_df["BESS_label"]=="it1"]
# Out:
#    overall_level  BESS BESS_label
# 2            Bad     0        it1
# 4            Bad     5        it1
# 8            Bad     3        it1
# 34           Bad     0        it1
# 38           Bad     2        it1
# 40           Bad     2        it1
# 41           Bad     1        it1
# 42           Bad     5        it1

# %%
b = sns.barplot(x="BESS_label", y="BESS", hue = "overall_level",data = barplot_df_system, hue_order = ["Good", "Moderate", "Bad"], palette = ["green", "yellow", "red"]);
b.set_xticklabels(["Lifting foot", "Moving hip", "Stepping", "Lifting hand", "Out pos >5"])
plt.ylim(0, 8)
# Out:
# (0.0, 8.0)

# %% [markdown]
# ### What is the correlation between each assessment?
# *	Correlation test (total score correlation)
# *	T-test (continues)
# *	Human (BESS-5) vs system (BESS-5)
# *	Deviation between human and system for each level

# %%
Automated_compared_df = Automated_sorted_df[(Automated_sorted_df['sub_ID'].isin(classification_df['sub_ID']))].reset_index(drop=True)
Comparison_sorted_df = classification_df[(classification_df['sub_ID'].isin(Automated_compared_df['sub_ID']))].reset_index(drop=True)

# %%
count = 0
for i in Automated_sorted_df['sub_ID'].isin(classification_df['sub_ID']):
    if i == 0:
        print(Automated_sorted_df['sub_ID'][count])
    count = count + 1
# Out:
# sub_12_EP_W2

# %%
Comparison_sorted_df.head()
# Out:
#          sub_ID J_rate    A_rate E_rate  overall_subjective_assessment  \
# 0  sub_01_EC_W2   Good      Good   Good                       2.333333
# 1  sub_01_EP_W2   Good      Good   Good                       0.333333
# 2  sub_02_EC_W2    Bad       Bad    Bad                       8.000000
# 3  sub_02_EP_W2   Good      Good   Good                       0.833333
# 4  sub_03_EC_W2    Bad  Moderate    Bad                       6.666667
#
#    overall_BESS_assessment overall_rate  overall_it1  overall_it2  \
# 0                 2.333333         Good     1.000000     1.333333
# 1                 0.333333         Good     0.333333     0.000000
# 2                17.000000          Bad     2.666667     6.000000
# 3                 0.000000         Good     0.000000     0.000000
# 4                10.000000          Bad     2.666667     3.000000
#
#    overall_it3  overall_it4  overall_it5 overall_level
# 0     0.000000     0.000000          0.0          Good
# 1     0.000000     0.000000          0.0          Good
# 2     4.666667     3.666667          0.0           Bad
# 3     0.000000     0.000000          0.0          Good
# 4     4.333333     0.000000          0.0           Bad

# %%
Comparison_sorted_df.iloc[:, 7:].to_csv("C:/Users/a1003/OneDrive/桌面/Thesis/data/trained_data_BESS/BESS_human_rating.csv")
Comparison_sorted_df.to_csv("C:/Users/a1003/OneDrive/桌面/Thesis/assessing/OLBT_evaluation_sheet.csv")

# %%
### correlation
overall_human_BESS_assessment = np.array(Comparison_sorted_df["overall_BESS_assessment"])
overall_system_BESS_assessment = np.array(Automated_compared_df["totel"])
overall_rate = np.array(Comparison_sorted_df["overall_rate"])
plt_df = pd.DataFrame({
    "Human_BESS": overall_human_BESS_assessment,
    "System_BESS":overall_system_BESS_assessment,
    "overall_rate":overall_rate
})
scipy.stats.pearsonr(overall_human_BESS_assessment, overall_system_BESS_assessment)
# Out:
# (0.8516873608999145, 8.720311523474638e-15)

# %%
x1, y1 = [-1, 25], [0, 0]
x2, y2 = [-1, 25], [Good_high_cut, Good_high_cut]
x3, y3 = [-1, 25], [Mod_low_cut, Mod_low_cut]
x4, y4 = [-1, 25], [Mod_high_cut, Mod_high_cut]
x5, y5 = [-1, 25], [Bad_low_cut, Bad_low_cut]
x6, y6 = [-1, 25], [Bad_high_cut, Bad_high_cut]

sns.lmplot(data = plt_df, x = "Human_BESS", y = "System_BESS", hue= "overall_rate", hue_order = ["Good", "Moderate", "Bad"], palette = ["green", "yellow", "red"], fit_reg=False)
sns.regplot(data = plt_df, x = "Human_BESS", y = "System_BESS", scatter=False)


plt.plot(x2, y2, color = "green" )
plt.plot(x3, y3, color = "yellow" )
plt.plot(x4, y4, color = "yellow" )
plt.plot(x5, y5, color = "red")
plt.xlim(-1, 26)
plt.ylim(-1, 26)
# Out:
# (-1.0, 26.0)

# %%
### T-test
stats.ttest_ind(overall_human_BESS_assessment, overall_system_BESS_assessment)
t = stats.ttest_ind(overall_human_BESS_assessment, overall_system_BESS_assessment).statistic
p = stats.ttest_ind(overall_human_BESS_assessment, overall_system_BESS_assessment).pvalue

print("t = {}, p = {}".format(t, p))
# Out:
# t = 0.12415914563630395, p = 0.9014488689767605

# %%
### mean
overall_human_BESS_assessment.mean(), overall_system_BESS_assessment.mean()
# Out:
# (5.850340136054422, 5.6938775510204085)

# %%
### std
overall_human_BESS_assessment.std(), overall_system_BESS_assessment.std()
# Out:
# (6.674166266220828, 5.6286587434585496)

# %%
### plot deviation
# barplot_df_human
# barplot_df_system

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
#Automated_compared_df.columns

# %%
#Comparison_sorted_df

# %%
deviation_df_human = Comparison_sorted_df[['overall_it1', 'overall_it2', 'overall_it3', 'overall_it4', 'overall_it5']]
deviation_df_system = Automated_compared_df[['foot_height_count', 'angle_count', 'stepping_count','hand_iliac_count', 'out_position_count']]

# %%
# 'foot_height_count'

rmse_deviation1 = rmse(np.array(deviation_df_system.iloc[:,0]), np.array(deviation_df_human.iloc[:,0]))
print("foot_height_count rmse: {}".format(rmse_deviation1))
# Out:
# foot_height_count rmse: 1.8455068928643907

# %%
#'angle_count'
rmse_deviation2 = rmse(np.array(deviation_df_system.iloc[:,1]), np.array(deviation_df_human.iloc[:,1]))
print("angle_count rmse: {}".format(rmse_deviation2))
# Out:
# angle_count rmse: 2.147613768338987

# %%
# 'stepping_count'
rmse_deviation3 = rmse(np.array(deviation_df_system.iloc[:,2]), np.array(deviation_df_human.iloc[:,2]))
print("stepping_count rmse: {}".format(rmse_deviation3))
# Out:
# stepping_count rmse: 0.8053111678708459

# %%
# 'hand_iliac_count'
rmse_deviation4 = rmse(np.array(deviation_df_system.iloc[:,3]), np.array(deviation_df_human.iloc[:,3]))
print("hand_iliac_count rmse: {}".format(rmse_deviation4))
# Out:
# hand_iliac_count rmse: 1.7076591501943912

# %%
# 'out_position_count'
rmse_deviation5 = rmse(np.array(deviation_df_system.iloc[:,4]), np.array(deviation_df_human.iloc[:,4]))
print("out_position_count rmse: {}".format(rmse_deviation5))
# Out:
# out_position_count rmse: 0.46899322865695736

# %%
(rmse_deviation1 + rmse_deviation2 + rmse_deviation3 + rmse_deviation4 + rmse_deviation5)/5
# Out:
# 1.3950168415851145

# %%
ax = plt.subplot()
sns.barplot(x = [1,2,3,4,5], y = [rmse_deviation1, rmse_deviation2, rmse_deviation3, rmse_deviation4, rmse_deviation5])
ax.set_xticklabels(['foot_height_count', 'angle_count', 'stepping_count', 'hand_iliac_count', 'out_position_count'])
plt.xticks(rotation = 30)
ax.set_ylabel("RMSE")
# Out:
# Text(0, 0.5, 'RMSE')

# %% [markdown]
# ## Can we build an hardcoded classification model to assess the performance of OLST?

# %%
automated_hardcoded_rating = []
for i in np.array(Automated_compared_df["totel"]):
    if i <= 4:
        automated_hardcoded_rating.append("Good")
    elif i <= 12 and i >= 5:
        automated_hardcoded_rating.append("Moderate")
    elif i > 12:
        automated_hardcoded_rating.append("Bad")

# %%
human_overall_rate = np.array(Comparison_sorted_df["overall_rate"])
hardcoded_overall_rate = automated_hardcoded_rating

human_hardcoded_comparion_df = pd.DataFrame({
    "human_overall_rate":human_overall_rate,
    "hardcoded_overall_rate":hardcoded_overall_rate
})

# %%
human_hardcoded_comparion_df
# Out:
#    human_overall_rate hardcoded_overall_rate
# 0                Good                   Good
# 1                Good                   Good
# 2                 Bad               Moderate
# 3                Good                   Good
# 4                 Bad                    Bad
# 5                Good                   Good
# 6                Good               Moderate
# 7                Good                   Good
# 8                 Bad                    Bad
# 9            Moderate               Moderate
# 10               Good                   Good
# 11               Good                   Good
# 12           Moderate               Moderate
# 13               Good                   Good
# 14               Good               Moderate
# 15               Good                   Good
# 16           Moderate               Moderate
# 17               Good                   Good
# 18           Moderate               Moderate
# 19               Good                   Good
# 20               Good               Moderate
# 21               Good                   Good
# 22           Moderate                   Good
# 23           Moderate                   Good
# 24               Good                   Good
# 25               Good                   Good
# 26               Good                   Good
# 27               Good                   Good
# 28               Good                   Good
# 29           Moderate                   Good
# 30               Good                   Good
# 31               Good                   Good
# 32               Good                   Good
# 33           Moderate               Moderate
# 34                Bad               Moderate
# 35               Good                   Good
# 36           Moderate               Moderate
# 37               Good                   Good
# 38                Bad                    Bad
# 39           Moderate                   Good
# 40                Bad                    Bad
# 41                Bad               Moderate
# 42                Bad                    Bad
# 43               Good                   Good
# 44           Moderate                    Bad
# 45               Good               Moderate
# 46               Good                   Good
# 47           Moderate                    Bad
# 48               Good                   Good

# %% [markdown]
# ## Accuracy

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

# %%
acc_3_t = accuracy_score(human_hardcoded_comparion_df['human_overall_rate'], human_hardcoded_comparion_df['hardcoded_overall_rate'])
cm_3_t = confusion_matrix(human_hardcoded_comparion_df['human_overall_rate'], human_hardcoded_comparion_df['hardcoded_overall_rate'])
recall = np.diag(cm_3_t) / np.sum(cm_3_t, axis = 1)
recall_3_t = np.mean(recall)
precision = np.diag(cm_3_t) / np.sum(cm_3_t, axis = 0)
precision_3_t = np.nanmean(precision)
print("acc: " + str(acc_3_t) + "\n" + "recall: " + str(recall_3_t) + "\n" + "precision: " + str(precision_3_t))
# Out:
# acc: 0.7346938775510204
# recall: 0.6623563218390804
# precision: 0.6792977137804724

# %% [markdown]
# ## Confusion Matrix

# %%
# confusion_matrix(comparison_df['Target'], comparison_df['prediction'], labels = labels)
labels = ["Good", "Moderate", "Bad"]
origin_cm = confusion_matrix(human_hardcoded_comparion_df['human_overall_rate'], human_hardcoded_comparion_df['hardcoded_overall_rate'], labels = labels)
transform_cm =confusion_matrix(human_hardcoded_comparion_df['human_overall_rate'], human_hardcoded_comparion_df['hardcoded_overall_rate'], labels = labels)
transform_cm[:,0] = origin_cm[:,2]
transform_cm[:,2] = origin_cm[:,0]
transform_cm
# Out:
# array([[ 0,  4, 25],
#        [ 2,  6,  4],
#        [ 5,  3,  0]], dtype=int64)

# %%
transform_1 = np.array([[transform_cm[2,2], transform_cm[2,1], transform_cm[2,0]],
                 [transform_cm[1,2], transform_cm[1,1], transform_cm[1,0]],
                 [transform_cm[0,2], transform_cm[0,1], transform_cm[0,0]]
                ])

# %%
#labels = comparison_df['prediction'].unique()

cm = transform_1
ax= plt.subplot()
sns.heatmap(cm, ax = ax, annot=True, cmap="Blues")
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_xticklabels(labels)
ax.set_yticklabels(["Bad", "Moderate", "Good"])
# Out:
# [Text(0, 0.5, 'Bad'), Text(0, 1.5, 'Moderate'), Text(0, 2.5, 'Good')]

# %%
transform_cm[2,0]
# Out:
# 5

# %% [markdown]
# ## Can we build an unsupervised classification model to assess the performance of OLST?

# %% [markdown]
# ## Can we build a supervised classification model to assess the performance of OLST based on gait feature?
# *	What feature make the model perform better?
# *	Which model works the best?

# %%
plt.scatter(overall_subjective_assessment, overall_BESS_assessment)
plt.xlabel("Subjective assessment score (average)")
plt.ylabel("Objective assessment (BESS) score (average)")
# Out:
# Text(0, 0.5, 'Objective assessment (BESS) score (average)')

# %%
new_df['sub_ID'] = sub_ID

# %%
np.array(new_df['overall_it1'])
# Out:
# array([1.        , 0.33333333, 2.66666667, 0.        , 2.66666667,
#        0.66666667, 0.66666667, 0.        , 6.        , 2.66666667,
#        1.33333333, 0.33333333, 2.        , 0.        , 2.        ,
#        0.        , 3.66666667, 0.33333333, 3.66666667, 0.        ,
#        7.33333333, 0.        , 0.66666667, 1.        , 0.        ,
#        1.66666667, 0.        , 1.        , 0.        , 2.33333333,
#        0.33333333, 2.33333333, 0.        , 4.33333333, 0.66666667,
#        2.66666667, 0.33333333, 2.33333333, 0.33333333, 2.66666667,
#        0.66666667, 6.66666667, 6.66666667, 8.        , 1.66666667,
#        6.33333333, 1.66666667, 2.33333333, 2.66666667, 3.        ,
#        0.        , 4.66666667, 1.        , 8.66666667, 0.        ])

# %%
classification_df["overall_it1"]=np.array(new_df['overall_it1']) 
classification_df["overall_it2"]=np.array(new_df['overall_it2']) 
classification_df["overall_it3"]=np.array(new_df['overall_it3']) 
classification_df["overall_it4"]=np.array(new_df['overall_it4']) 
classification_df["overall_it5"]=np.array(new_df['overall_it5'])

# %%
Automated_system_raw_df = pd.read_csv("C:/Users/a1003/OneDrive/桌面/Thesis/excel_csv/new_assessment/automated_system_assessment.csv")
Automated_system_raw_df = Automated_system_raw_df.drop(["Unnamed: 0"], axis = 1)
Automated_sorted_df = Automated_system_raw_df.sort_values('sub_ID')

# %%
Automated_sorted_df
# Out:
#           sub_ID  foot_height_count  angle_count  stepping_count  \
# 0   sub_01_EC_W2                  0            0               0
# 1   sub_01_EP_W2                  2            0               0
# 2   sub_02_EC_W2                  0            3               0
# 3   sub_02_EP_W2                  3            0               0
# 4   sub_03_EC_W2                  2            4               1
# 5   sub_03_EP_W2                  2            0               0
# 6   sub_04_EC_W2                  2            0               0
# 7   sub_04_EP_W2                  2            0               0
# 8   sub_05_EC_W2                  5            4               5
# 9   sub_05_EP_W2                  3            0               0
# 10  sub_06_EC_W2                  3            0               0
# 11  sub_06_EP_W2                  3            0               0
# 12  sub_07_EC_W2                  0            2               0
# 13  sub_08_EP_W2                  1            0               0
# 14  sub_09_EC_W2                  3            3               0
# 15  sub_09_EP_W2                  2            0               0
# 16  sub_10_EC_W2                  0            6               0
# 17  sub_11_EC_W2                  2            2               0
# 18  sub_11_EP_W2                  0            0               0
# 19  sub_12_EC_W2                  0            0               0
# 20  sub_12_EP_W2                  0            0               0
# 21  sub_13_EC_W2                  0            2               1
# 22  sub_13_EP_W2                  2            0               0
# 23  sub_14_EC_W2                  2            0               0
# 24  sub_14_EP_W2                  0            0               0
# 25  sub_16_EC_W2                  1            0               0
# 26  sub_16_EP_W2                  1            0               0
# 27  sub_17_EC_W2                  1            0               0
# 28  sub_17_EP_W2                  0            0               0
# 29  sub_18_EC_W2                  5            5               1
# 30  sub_19_EC_W2                  0            2               0
# 31  sub_19_EP_W2                  0            0               0
# 32  sub_23_EC_W2                  8            0               0
# 33  sub_23_EP_W2                  2            0               0
# 34  sub_24_EC_W2                  1           11               5
# 35  sub_24_EP_W2                  0            3               0
# 36  sub_25_EC_W2                  1            8               4
# 37  sub_25_EP_W2                  0            5               2
# 38  sub_26_EC_W2                  3            9               3
# 39  sub_26_EP_W2                  1            0               0
# 40  sub_27_EC_W2                  2            6               0
# 41  sub_29_EC_W2                  1            2               0
# 42  sub_30_EC_W2                  3            8               0
# 43  sub_30_EP_W2                  1            0               0
#
#     hand_iliac_count  out_position_count  totel
# 0                  4                   0      4
# 1                  1                   0      3
# 2                  1                   0      4
# 3                  0                   0      3
# 4                  0                   0      7
# 5                  1                   0      3
# 6                  6                   0      8
# 7                  0                   0      2
# 8                  3                   0     17
# 9                  3                   0      6
# 10                 1                   0      4
# 11                 2                   0      5
# 12                 0                   0      2
# 13                 0                   0      1
# 14                 0                   0      6
# 15                 0                   0      2
# 16                 2                   0      8
# 17                 0                   0      4
# 18                 0                   0      0
# 19                 1                   0      1
# 20                 2                   0      2
# 21                 0                   0      3
# 22                 0                   0      2
# 23                 0                   0      2
# 24                 1                   0      1
# 25                 0                   0      1
# 26                 0                   0      1
# 27                 0                   0      1
# 28                 0                   0      0
# 29                 0                   0     11
# 30                 2                   0      4
# 31                 1                   0      1
# 32                 0                   0      8
# 33                 0                   0      2
# 34                 0                   0     17
# 35                 1                   0      4
# 36                 0                   0     13
# 37                 0                   0      7
# 38                 4                   0     19
# 39                 0                   0      1
# 40                 0                   0      8
# 41                 0                   0      3
# 42                 1                   0     12
# 43                 1                   0      2

# %%
Automated_compared_df = Automated_sorted_df[(Automated_sorted_df['sub_ID'].isin(classification_df['sub_ID']))].reset_index(drop=True)
Comparison_sorted_df = classification_df[(classification_df['sub_ID'].isin(Automated_compared_df['sub_ID']))].reset_index(drop=True)

# %%
Automated_compared_df
# Out:
#           sub_ID  foot_height_count  angle_count  stepping_count  \
# 0   sub_01_EC_W2                  0            0               0
# 1   sub_01_EP_W2                  2            0               0
# 2   sub_02_EC_W2                  0            3               0
# 3   sub_02_EP_W2                  3            0               0
# 4   sub_03_EC_W2                  2            4               1
# 5   sub_03_EP_W2                  2            0               0
# 6   sub_04_EC_W2                  2            0               0
# 7   sub_04_EP_W2                  2            0               0
# 8   sub_05_EC_W2                  5            4               5
# 9   sub_05_EP_W2                  3            0               0
# 10  sub_06_EC_W2                  3            0               0
# 11  sub_06_EP_W2                  3            0               0
# 12  sub_07_EC_W2                  0            2               0
# 13  sub_08_EP_W2                  1            0               0
# 14  sub_09_EC_W2                  3            3               0
# 15  sub_09_EP_W2                  2            0               0
# 16  sub_10_EC_W2                  0            6               0
# 17  sub_11_EC_W2                  2            2               0
# 18  sub_11_EP_W2                  0            0               0
# 19  sub_12_EC_W2                  0            0               0
# 20  sub_13_EC_W2                  0            2               1
# 21  sub_13_EP_W2                  2            0               0
# 22  sub_14_EC_W2                  2            0               0
# 23  sub_14_EP_W2                  0            0               0
# 24  sub_16_EC_W2                  1            0               0
# 25  sub_16_EP_W2                  1            0               0
# 26  sub_17_EC_W2                  1            0               0
# 27  sub_17_EP_W2                  0            0               0
# 28  sub_18_EC_W2                  5            5               1
# 29  sub_19_EC_W2                  0            2               0
# 30  sub_19_EP_W2                  0            0               0
# 31  sub_23_EC_W2                  8            0               0
# 32  sub_23_EP_W2                  2            0               0
# 33  sub_24_EC_W2                  1           11               5
# 34  sub_24_EP_W2                  0            3               0
# 35  sub_25_EC_W2                  1            8               4
# 36  sub_25_EP_W2                  0            5               2
# 37  sub_26_EC_W2                  3            9               3
# 38  sub_26_EP_W2                  1            0               0
# 39  sub_27_EC_W2                  2            6               0
# 40  sub_29_EC_W2                  1            2               0
# 41  sub_30_EC_W2                  3            8               0
# 42  sub_30_EP_W2                  1            0               0
#
#     hand_iliac_count  out_position_count  totel
# 0                  4                   0      4
# 1                  1                   0      3
# 2                  1                   0      4
# 3                  0                   0      3
# 4                  0                   0      7
# 5                  1                   0      3
# 6                  6                   0      8
# 7                  0                   0      2
# 8                  3                   0     17
# 9                  3                   0      6
# 10                 1                   0      4
# 11                 2                   0      5
# 12                 0                   0      2
# 13                 0                   0      1
# 14                 0                   0      6
# 15                 0                   0      2
# 16                 2                   0      8
# 17                 0                   0      4
# 18                 0                   0      0
# 19                 1                   0      1
# 20                 0                   0      3
# 21                 0                   0      2
# 22                 0                   0      2
# 23                 1                   0      1
# 24                 0                   0      1
# 25                 0                   0      1
# 26                 0                   0      1
# 27                 0                   0      0
# 28                 0                   0     11
# 29                 2                   0      4
# 30                 1                   0      1
# 31                 0                   0      8
# 32                 0                   0      2
# 33                 0                   0     17
# 34                 1                   0      4
# 35                 0                   0     13
# 36                 0                   0      7
# 37                 4                   0     19
# 38                 0                   0      1
# 39                 0                   0      8
# 40                 0                   0      3
# 41                 1                   0     12
# 42                 1                   0      2

# %%
Comparison_sorted_df
# Out:
#           sub_ID    J_rate    A_rate    E_rate  overall_subjective_assessment  \
# 0   sub_01_EC_W2      Good      Good      Good                       2.333333
# 1   sub_01_EP_W2      Good      Good      Good                       0.333333
# 2   sub_02_EC_W2       Bad       Bad       Bad                       8.000000
# 3   sub_02_EP_W2      Good      Good      Good                       0.833333
# 4   sub_03_EC_W2       Bad  Moderate       Bad                       6.666667
# 5   sub_03_EP_W2      Good      Good      Good                       1.000000
# 6   sub_04_EC_W2      Good      Good      Good                       0.000000
# 7   sub_04_EP_W2      Good      Good      Good                       0.000000
# 8   sub_05_EC_W2       Bad  Moderate       Bad                       7.333333
# 9   sub_05_EP_W2  Moderate      Good  Moderate                       2.000000
# 10  sub_06_EC_W2      Good      Good      Good                       0.500000
# 11  sub_06_EP_W2      Good      Good      Good                       0.166667
# 12  sub_07_EC_W2  Moderate  Moderate  Moderate                       5.333333
# 13  sub_08_EP_W2      Good      Good      Good                       0.000000
# 14  sub_09_EC_W2  Moderate  Moderate  Moderate                       3.833333
# 15  sub_09_EP_W2      Good      Good      Good                       0.666667
# 16  sub_10_EC_W2  Moderate  Moderate  Moderate                       5.833333
# 17  sub_11_EC_W2  Moderate      Good      Good                       2.000000
# 18  sub_11_EP_W2      Good      Good      Good                       0.000000
# 19  sub_12_EC_W2  Moderate  Moderate  Moderate                       3.666667
# 20  sub_13_EC_W2  Moderate  Moderate  Moderate                       4.333333
# 21  sub_13_EP_W2      Good      Good      Good                       0.833333
# 22  sub_14_EC_W2      Good      Good      Good                       1.666667
# 23  sub_14_EP_W2      Good      Good      Good                       0.000000
# 24  sub_16_EC_W2  Moderate  Moderate      Good                       2.666667
# 25  sub_16_EP_W2      Good      Good      Good                       1.000000
# 26  sub_17_EC_W2      Good      Good      Good                       0.333333
# 27  sub_17_EP_W2      Good      Good      Good                       0.000000
# 28  sub_18_EC_W2  Moderate  Moderate       Bad                       6.500000
# 29  sub_19_EC_W2       Bad  Moderate       Bad                       6.666667
# 30  sub_19_EP_W2      Good      Good      Good                       1.166667
# 31  sub_23_EC_W2      Good  Moderate  Moderate                       3.500000
# 32  sub_23_EP_W2      Good      Good      Good                       0.833333
# 33  sub_24_EC_W2       Bad       Bad       Bad                       7.500000
# 34  sub_24_EP_W2  Moderate  Moderate      Good                       3.666667
# 35  sub_25_EC_W2       Bad       Bad       Bad                       8.500000
# 36  sub_25_EP_W2       Bad  Moderate       Bad                       7.000000
# 37  sub_26_EC_W2       Bad  Moderate       Bad                       7.166667
# 38  sub_26_EP_W2      Good      Good      Good                       1.166667
# 39  sub_27_EC_W2  Moderate  Moderate  Moderate                       5.166667
# 40  sub_29_EC_W2      Good      Good      Good                       1.166667
# 41  sub_30_EC_W2      Good       Bad  Moderate                       4.166667
# 42  sub_30_EP_W2      Good      Good      Good                       1.500000
#
#     overall_BESS_assessment overall_rate  overall_it1  overall_it2  \
# 0                  2.333333         Good     1.000000     1.333333
# 1                  0.333333         Good     0.333333     0.000000
# 2                 17.000000          Bad     2.666667     6.000000
# 3                  0.000000         Good     0.000000     0.000000
# 4                 10.000000          Bad     2.666667     3.000000
# 5                  1.666667         Good     0.666667     0.000000
# 6                  0.666667         Good     0.666667     0.000000
# 7                  0.000000         Good     0.000000     0.000000
# 8                 21.333333          Bad     6.000000     4.666667
# 9                  2.666667     Moderate     2.666667     0.000000
# 10                 2.333333         Good     1.333333     0.000000
# 11                 0.666667         Good     0.333333     0.000000
# 12                11.666667     Moderate     2.000000     6.666667
# 13                 0.000000         Good     0.000000     0.000000
# 14                 6.666667     Moderate     3.666667     1.333333
# 15                 0.333333         Good     0.333333     0.000000
# 16                15.333333     Moderate     3.666667    10.333333
# 17                 8.333333         Good     7.333333     1.000000
# 18                 0.000000         Good     0.000000     0.000000
# 19                 5.000000     Moderate     0.666667     2.000000
# 20                 7.666667     Moderate     1.000000     5.333333
# 21                 1.666667         Good     0.000000     1.666667
# 22                 3.666667         Good     1.666667     1.000000
# 23                 0.000000         Good     0.000000     0.000000
# 24                 5.333333     Moderate     2.333333     1.000000
# 25                 1.333333         Good     0.333333     0.000000
# 26                 2.666667         Good     2.333333     0.333333
# 27                 0.000000         Good     0.000000     0.000000
# 28                12.000000     Moderate     4.333333     3.666667
# 29                11.000000          Bad     2.666667     6.000000
# 30                 0.666667         Good     0.333333     0.000000
# 31                 6.000000     Moderate     2.333333     0.000000
# 32                 0.333333         Good     0.333333     0.000000
# 33                16.000000          Bad     2.666667     7.333333
# 34                 5.333333     Moderate     0.666667     3.666667
# 35                22.333333          Bad     6.666667     8.333333
# 36                18.666667          Bad     6.666667     9.666667
# 37                24.333333          Bad     8.000000     6.666667
# 38                 3.333333         Good     1.666667     1.666667
# 39                12.666667     Moderate     6.333333     1.333333
# 40                 5.666667         Good     3.000000     2.666667
# 41                10.666667     Moderate     4.666667     0.000000
# 42                 2.333333         Good     1.000000     0.000000
#
#     overall_it3  overall_it4  overall_it5 overall_level
# 0      0.000000     0.000000     0.000000          Good
# 1      0.000000     0.000000     0.000000          Good
# 2      4.666667     3.666667     0.000000           Bad
# 3      0.000000     0.000000     0.000000          Good
# 4      4.333333     0.000000     0.000000           Bad
# 5      0.000000     1.000000     0.000000          Good
# 6      0.000000     0.000000     0.000000          Good
# 7      0.000000     0.000000     0.000000          Good
# 8      6.333333     3.333333     1.000000           Bad
# 9      0.000000     0.000000     0.000000      Moderate
# 10     0.000000     1.000000     0.000000          Good
# 11     0.000000     0.333333     0.000000          Good
# 12     3.000000     0.000000     0.000000      Moderate
# 13     0.000000     0.000000     0.000000          Good
# 14     1.666667     0.000000     0.000000      Moderate
# 15     0.000000     0.000000     0.000000          Good
# 16     0.000000     1.000000     0.333333      Moderate
# 17     0.000000     0.000000     0.000000          Good
# 18     0.000000     0.000000     0.000000          Good
# 19     2.000000     0.333333     0.000000      Moderate
# 20     1.333333     0.000000     0.000000      Moderate
# 21     0.000000     0.000000     0.000000          Good
# 22     1.000000     0.000000     0.000000          Good
# 23     0.000000     0.000000     0.000000          Good
# 24     2.000000     0.000000     0.000000      Moderate
# 25     1.000000     0.000000     0.000000          Good
# 26     0.000000     0.000000     0.000000          Good
# 27     0.000000     0.000000     0.000000          Good
# 28     4.000000     0.000000     0.000000      Moderate
# 29     0.666667     1.333333     0.333333           Bad
# 30     0.000000     0.333333     0.000000          Good
# 31     3.666667     0.000000     0.000000      Moderate
# 32     0.000000     0.000000     0.000000          Good
# 33     5.666667     0.000000     0.333333           Bad
# 34     1.000000     0.000000     0.000000      Moderate
# 35     4.333333     0.000000     3.000000           Bad
# 36     2.333333     0.000000     0.000000           Bad
# 37     5.666667     3.333333     0.666667           Bad
# 38     0.000000     0.000000     0.000000          Good
# 39     5.000000     0.000000     0.000000      Moderate
# 40     0.000000     0.000000     0.000000          Good
# 41     5.333333     0.666667     0.000000      Moderate
# 42     0.333333     1.000000     0.000000          Good

# %%
np.corrcoef(Automated_compared_df["totel"], Comparison_sorted_df["overall_BESS_assessment"])
# Out:
# array([[1.      , 0.787919],
#        [0.787919, 1.      ]])

# %%
np.corrcoef(Automated_compared_df["foot_height_count"], Comparison_sorted_df["overall_it1"])
# Out:
# array([[1.        , 0.24110308],
#        [0.24110308, 1.        ]])

# %%
np.corrcoef(Automated_compared_df["angle_count"], Comparison_sorted_df["overall_it2"])
# Out:
# array([[1.        , 0.70146515],
#        [0.70146515, 1.        ]])

# %%
np.corrcoef(Automated_compared_df["stepping_count"], Comparison_sorted_df["overall_it3"])
# Out:
# array([[1.        , 0.67078666],
#        [0.67078666, 1.        ]])

# %%
np.corrcoef(Automated_compared_df["hand_iliac_count"], Comparison_sorted_df["overall_it4"])
# Out:
# array([[1.        , 0.42298601],
#        [0.42298601, 1.        ]])

# %%
np.corrcoef(Automated_compared_df["out_position_count"], Comparison_sorted_df["overall_it5"])
# Out:
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\numpy\lib\function_base.py:2691: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\a1003\anaconda3\envs\py3-TF2.0\lib\site-packages\numpy\lib\function_base.py:2692: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# array([[nan, nan],
#        [nan,  1.]])

# %%
Automated_compared_df["totel"] - Comparison_sorted_df["overall_it1"]
# Out:
# 0      3.000000
# 1      2.666667
# 2      1.333333
# 3      3.000000
# 4      4.333333
# 5      2.333333
# 6      7.333333
# 7      2.000000
# 8     11.000000
# 9      3.333333
# 10     2.666667
# 11     4.666667
# 12     0.000000
# 13     1.000000
# 14     2.333333
# 15     1.666667
# 16     4.333333
# 17    -3.333333
# 18     0.000000
# 19     0.333333
# 20     2.000000
# 21     2.000000
# 22     0.333333
# 23     1.000000
# 24    -1.333333
# 25     0.666667
# 26    -1.333333
# 27     0.000000
# 28     6.666667
# 29     1.333333
# 30     0.666667
# 31     5.666667
# 32     1.666667
# 33    14.333333
# 34     3.333333
# 35     6.333333
# 36     0.333333
# 37    11.000000
# 38    -0.666667
# 39     1.666667
# 40     0.000000
# 41     7.333333
# 42     1.000000
# dtype: float64

# %%
count = 0
for i in (classification_df['sub_ID'].isin(Automated_compared_df['sub_ID']) == 0):
    if i == 1:
        print(list(classification_df['sub_ID'])[count])
    count = count + 1
# Out:
# sub_07_EP_W2
# sub_08_EC_W2
# sub_10_EP_W2
# sub_15_EC_W2
# sub_15_EP_W2
# sub_18_EP_W2
# sub_27_EP_W2
# sub_28_EC_W2
# sub_28_EP_W2
# sub_29_EP_W2
# sub_31_EC_W2
# sub_31_EP_W2

# %%
#Comparison_sorted_df.to_csv("C:/Users/a1003/OneDrive/桌面/Thesis/assessing/OLBT_evaluation_sheet.csv")

# %%
Comparison_sorted_df[["sub_ID","overall_BESS_assessment", "overall_rate", "overall_it1"]][Comparison_sorted_df["overall_it1"]>=5]
# Out:
#           sub_ID  overall_BESS_assessment overall_rate  overall_it1
# 8   sub_05_EC_W2                21.333333          Bad     6.000000
# 17  sub_11_EC_W2                 8.333333         Good     7.333333
# 35  sub_25_EC_W2                22.333333          Bad     6.666667
# 36  sub_25_EP_W2                18.666667          Bad     6.666667
# 37  sub_26_EC_W2                24.333333          Bad     8.000000
# 39  sub_27_EC_W2                12.666667     Moderate     6.333333

# %%
Automated_compared_df[["sub_ID", "foot_height_count"]][Automated_compared_df["sub_ID"].isin(Comparison_sorted_df["sub_ID"][Comparison_sorted_df["overall_it1"]>=5])]
# Out:
#           sub_ID  foot_height_count
# 8   sub_05_EC_W2                  5
# 17  sub_11_EC_W2                  2
# 35  sub_25_EC_W2                  1
# 36  sub_25_EP_W2                  0
# 37  sub_26_EC_W2                  3
# 39  sub_27_EC_W2                  2
